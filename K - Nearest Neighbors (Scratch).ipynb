# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
from collections import Counter

# %%
style.use('fivethirtyeight')

# %%
dataset = {'k': [[1,2],[2,3],[3,1]], 'r': [[6,5],[7,7],[8,6]]}

# %%
dataset
# Out:
# {'k': [[1, 2], [2, 3], [3, 1]], 'r': [[6, 5], [7, 7], [8, 6]]}

# %%
# Using for loop to plot data - Visualization

# %%
for i in dataset:
    for ii in dataset[i]:
        plt.scatter(ii[0],ii[1], s=100, color=i)

# %%
# One liner code for above plot

# %%
[[(plt.scatter(ii[0], ii[1], s=100, color=i)) for ii in dataset [i]] for i in dataset]
# Out:
# [[<matplotlib.collections.PathCollection at 0x203f06ff080>,
#   <matplotlib.collections.PathCollection at 0x203f06ff438>,
#   <matplotlib.collections.PathCollection at 0x203f06ff358>],
#  [<matplotlib.collections.PathCollection at 0x203f06ff780>,
#   <matplotlib.collections.PathCollection at 0x203f06ffa90>,
#   <matplotlib.collections.PathCollection at 0x203f070f128>]]

# %%
new_features = [5,7]

# %%
plt.scatter(new_features[0], new_features[1])

# %%
# combine both

# %%
[[(plt.scatter(ii[0], ii[1], s=100, color=i)) for ii in dataset [i]] for i in dataset]
plt.scatter(new_features[0], new_features[1])
